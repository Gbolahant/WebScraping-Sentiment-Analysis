# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.8.0.tar.gz (19 kB)
# Requirement already satisfied: requests>=2.0 in c:\users\transsnet\miniconda3\lib\site-packages (from pytrends) (2.27.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\transsnet\miniconda3\lib\site-packages (from pytrends) (1.4.4)
# Requirement already satisfied: lxml in c:\users\transsnet\miniconda3\lib\site-packages (from pytrends) (4.9.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\transsnet\miniconda3\lib\site-packages (from pandas>=0.25->pytrends) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\transsnet\miniconda3\lib\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\transsnet\miniconda3\lib\site-packages (from pandas>=0.25->pytrends) (1.23.1)
# Requirement already satisfied: six>=1.5 in c:\users\transsnet\miniconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\transsnet\miniconda3\lib\site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\transsnet\miniconda3\lib\site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\transsnet\miniconda3\lib\site-packages (from requests>=2.0->pytrends) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\transsnet\miniconda3\lib\site-packages (from requests>=2.0->pytrends) (1.26.8)
# Building wheels for collected packages: pytrends
#   Building wheel for pytrends (setup.py): started
#   Building wheel for pytrends (setup.py): finished with status 'done'
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16126 sha256=978f75f9665ee54e88482eb258df37493847d360e281fef2c98f0fcb07f1df82
#   Stored in directory: c:\users\transsnet\appdata\local\pip\cache\wheels\87\a9\a3\c190a7e0872639762e92cf3a84d6845ed086e10966533faf42
# Successfully built pytrends
# Installing collected packages: pytrends
# Successfully installed pytrends-4.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='en-US', tz=360)
pytrends.build_payload(kw_list=['Far From Home Netflix'], timeframe='today 1-m')
trend_data = pytrends.interest_over_time()
related_topics = pytrends.related_topics()
related_queries = pytrends.related_queries()
region_data = pytrends.interest_by_region()

# %%
region_data =region_data[(region_data != 0).all(1)]

# %%
region_data
# Out:
#                       Far From Home Netflix
# geoName
# Benin                                    38
# Canada                                    2
# Côte d’Ivoire                             7
# France                                    1
# Ghana                                    29
# Ireland                                   3
# Jamaica                                  31
# Kenya                                     8
# Malaysia                                  2
# Morocco                                   2
# Namibia                                  16
# Nigeria                                 100
# South Africa                              5
# Sweden                                    1
# Uganda                                   10
# United Arab Emirates                      1
# United Kingdom                            2
# United States                             1
# Zimbabwe                                 22

# %%
related_queries
# Out:
# {'Far From Home Netflix': {'top':                                    query  value
#   0             netflix far from home cast    100
#   1                     far from home cast     96
#   2           far from home netflix series     38
#   3                   far from home series     38
#   4         download far from home netflix     36
#   5          far from home netflix nigeria     35
#   6             far from home netflix 2022     19
#   7                far from home nollywood     18
#   8                         netflix movies     18
#   9        far from home netflix nollywood     17
#   10    far from home netflix cast nigeria     16
#   11            far away from home netflix     16
#   12         cast of far from home netflix     15
#   13                    far away from home     14
#   14             far from home series cast     14
#   15  far from home netflix movie download     14
#   16     far from home netflix series cast     13
#   17                 cast of far from home     13
#   18                far from home season 2     12
#   19          far from home nigerian movie     12
#   20        far from home netflix season 2     12
#   21           far from home serie netflix     10
#   22        far from home netflix episodes      9
#   23                          elma mbadiwe      9
#   24                         mike afolarin      9,
#   'rising':                                    query    value
#   0             netflix far from home cast  2583150
#   1                     far from home cast  2489350
#   2         download far from home netflix   939500
#   3          far from home netflix nigeria   901500
#   4             far from home netflix 2022   490100
#   5                far from home nollywood   471700
#   6        far from home netflix nollywood   439800
#   7     far from home netflix cast nigeria   424900
#   8             far away from home netflix   413600
#   9                     far away from home   364600
#   10             far from home series cast   359650
#   11  far from home netflix movie download   354850
#   12     far from home netflix series cast   347400
#   13                 cast of far from home   342000
#   14                far from home season 2   321050
#   15          far from home nigerian movie   314400
#   16        far from home netflix season 2   304250
#   17           far from home serie netflix   256600
#   18                          elma mbadiwe   232550
#   19                         mike afolarin   227200
#   20                              netnaija   211200
#   21          far from home cast nollywood   208100
#   22                          natse jemide   206100
#   23          reggie far from home netflix   168050
#   24               spiderman far from home   149450}}
